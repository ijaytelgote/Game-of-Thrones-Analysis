# %%
import pandas as pd
import numpy as np
battle=pd.read_csv(r'C:\Users\jayma\Downloads\battles.csv')

# %%
battle.head()
# Out:
#                             name  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king attacker_1 attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
#to know the no of rows and no of columns we use .shape method
battle.shape
# Out:
# (38, 25)

# %%
#to rename the column we use this,
battle.rename(columns={'name':'operations'},inplace=True)
battle.head()
# Out:
#                       operations  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king P Attacker attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
battle.head()
# Out:
#                       operations  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king P Attacker attacker_2  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister        NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark        NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark      Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
battle.rename(columns={'attacker_2':'looser_1'},inplace=True)

# %%
battle.head()
# Out:
#                       operations  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king P Attacker looser_1  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister      NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister      NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister      NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark      NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark    Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
battle.rename(columns={'P Attacker':'looser'},inplace=True)

# %%
battle.head()
# Out:
#                       operations  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king     looser looser_1  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister      NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister      NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister      NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark      NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark    Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
#if wanna know the no of time the attacker attack we use value_count() method
battle['attacker_king'].value_counts()
# Out:
# Joffrey/Tommen Baratheon    14
# Robb Stark                  10
# Balon/Euron Greyjoy          7
# Stannis Baratheon            5
# Name: attacker_king, dtype: int64

# %%
#no of times the loosers lose the match
battle['looser'].value_counts()
# Out:
# Lannister                      8
# Stark                          8
# Greyjoy                        7
# Baratheon                      6
# Bolton                         2
# Frey                           2
# Darry                          1
# Brotherhood without Banners    1
# Free folk                      1
# Brave Companions               1
# Bracken                        1
# Name: looser, dtype: int64

# %%
battle['location'].value_counts()
# Out:
# Riverrun                                3
# Winterfell                              3
# Storm's End                             2
# Harrenhal                               2
# Darry                                   2
# Moat Cailin                             2
# Deepwood Motte                          2
# Torrhen's Square                        2
# Golden Tooth                            1
# Seagard                                 1
# Castle Black                            1
# Shield Islands                          1
# Saltpans                                1
# Ruby Ford                               1
# Ryamsport, Vinetown, Starfish Harbor    1
# Dragonstone                             1
# The Twins                               1
# Red Fork                                1
# Duskendale                              1
# King's Landing                          1
# Crag                                    1
# Mummer's Ford                           1
# ...

# %%
#to do visualization we use seaborn lib
import seaborn as sb
from matplotlib import pyplot as plt

# %%
sb.set(rc={'figure.figsize':(13,5)})
sb.barplot(x='attacker_king',y='attacker_size',data=battle)
plt.show()

# %%
sb.set(rc={'figure.figsize':(13,5)})
sb.barplot(x='defender_king',y='defender_size',data=battle)
plt.show()

# %%
sb.set(rc={'figure.figsize':(19,4)})
sb.barplot(x='year',y='battle_number',data=battle)
plt.show()

# %%
battle.head()
# Out:
#                       operations  year  battle_number  \
# 0     Battle of the Golden Tooth   298              1
# 1    Battle at the Mummer's Ford   298              2
# 2             Battle of Riverrun   298              3
# 3       Battle of the Green Fork   298              4
# 4  Battle of the Whispering Wood   298              5
#
#               attacker_king             defender_king     looser looser_1  \
# 0  Joffrey/Tommen Baratheon                Robb Stark  Lannister      NaN
# 1  Joffrey/Tommen Baratheon                Robb Stark  Lannister      NaN
# 2  Joffrey/Tommen Baratheon                Robb Stark  Lannister      NaN
# 3                Robb Stark  Joffrey/Tommen Baratheon      Stark      NaN
# 4                Robb Stark  Joffrey/Tommen Baratheon      Stark    Tully
#
#   attacker_3 attacker_4 defender_1  ... major_death  major_capture  \
# 0        NaN        NaN      Tully  ...         1.0            0.0
# ...

# %%
sb.countplot(x=battle['attacker_king'],hue=battle['battle_type'])
plt.show()

# %%
death=pd.read_csv(r'C:\Users\jayma\AppData\Local\Temp\Temp1_archive (11).zip\character-deaths.csv')

# %%
death.head()
# Out:
#                       Name      Allegiances  Death Year  Book of Death  \
# 0           Addam Marbrand        Lannister         NaN            NaN
# 1  Aegon Frey (Jinglebell)             None       299.0            3.0
# 2          Aegon Targaryen  House Targaryen         NaN            NaN
# 3            Adrack Humble    House Greyjoy       300.0            5.0
# 4           Aemon Costayne        Lannister         NaN            NaN
#
#    Death Chapter  Book Intro Chapter  Gender  Nobility  GoT  CoK  SoS  FfC  \
# 0            NaN                56.0       1         1    1    1    1    1
# 1           51.0                49.0       1         1    0    0    1    0
# 2            NaN                 5.0       1         1    0    0    0    0
# 3           20.0                20.0       1         1    0    0    0    0
# 4            NaN                 NaN       1         1    0    0    1    0
#
#    DwD
# 0    0
# 1    0
# 2    1
# 3    1
# 4    0

# %%
death.shape
# Out:
# (917, 13)

# %%
death['Book of Death'].value_counts()
# Out:
# 3.0    97
# 2.0    73
# 5.0    61
# 1.0    49
# 4.0    27
# Name: Book of Death, dtype: int64

# %%
death['Book Intro Chapter'].value_counts()
# Out:
# 0.0     41
# 2.0     32
# 19.0    30
# 38.0    29
# 37.0    28
#         ..
# 80.0     1
# 78.0     1
# 72.0     1
# 79.0     1
# 74.0     1
# Name: Book Intro Chapter, Length: 79, dtype: int64

# %%
death['Gender'].value_counts()
# Out:
# 1    760
# 0    157
# Name: Gender, dtype: int64

# %%
death['Nobility'].value_counts()
# Out:
# 0    487
# 1    430
# Name: Nobility, dtype: int64

# %%
#how many no of deaths are occures
sb.countplot(death['Death Year'])
plt.show()
# Out:
# c:\Users\jayma\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.countplot(death['Death Chapter'])
plt.show()
# Out:
# c:\Users\jayma\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
sb.set(rc={'figure.figsize':(30,10)})
sb.countplot(death['Allegiances'])
plt.show()
# Out:
# c:\Users\jayma\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
